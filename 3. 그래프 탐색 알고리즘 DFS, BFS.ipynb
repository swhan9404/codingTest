# %%
"""
* 탐색이란 많은 양의 데이터 중에서 우너하는 데이터를 찾는 과정

** 스택 자료구조 - 먼저 들어 온 데이터가 나중에 나가는 형식(선입후출) 자료구조
* 스택 동작예시
삽입(5) - 삽입(2) - 삽입(3) - 삽입(7) - 삭제() - 삽입(1) -삽입(4) - 삭제()
>>5231

*스택 자료구조를 python에서 사용하는것은 리스트 자료구조를 사용
append() #삽입
pop() #삭제 # pop(자릿수) 몇번째 자리를 반환하고 제거

print(stack[::-1]) # 최상단 원소부터 출력
print(stack) #최하단 원소부터 출력
"""


"""
** 큐 자료구조 - 먼저 들어온 데이터가 먼저 나가는 형식(선입선출)
* 큐 동작 예시
삽입(5) - 삽입(2) - 삽입(3) - 삽입(7) - 삭제() - 삽입(1) -삽입(4) - 삭제()
>>3714

* 큐 자료구조는 python 에서 collections.deque를 사용 > list 사용시 시간 복잡도가 높음(비효율적)
from collections import deque

queue = deque()

append() #삽입
popleft() #삭제

print(queue) # 먼저 들어온 순서대로 출력 [3,7,1,4]
queue.reverse() # 역순으로 바꾸기
print(queue) # 나중에 들어온 원소부터 출력 [4,1,7,3]
"""

# %%
""" 재귀함수(Recursive Function) - 자기 자신을 다시 호출하는 함수
* python 은 재귀함수의 깊이 제한이 있어서 무한히 반복되는 재귀함수의 경우 반복되다가 오류메시지가 나오면서 종류됨.
* 실제로 컴퓨터 시스템 상에서 함수가 재귀적으로 호출되면 컴퓨터 시스템의 stack frame에 이러한 함수가 반복적으로 쌓여서 가장 마지막에 호출된 함수가 처리된 이후에 이제 그 함수를 불렀던 함수까지 처리
일종의 stack 자료형식으로  동작한다고 볼 수 있음. 즉, 일종의 stack 자료 구조안에 함수가 담겨서 메모리 안에 올라간다고 생각하면됨
당연히 컴퓨터 메모리는 한정된 메모리이기 때문에 재귀함수가 계속 쌓여서 호출만 하게되면 빠르게 메모리가 가득차서 이러한 재귀 깊이 제한을 걸어둘 수 있다.

그래서 만약 제한없이 재귀함수를 호출하려면, 2가지 방법이 존재
1. 재귀제한을 느슨하게 만든다.
2. 별도로 스택자료구조를 이용해서 스택을 객체를 따로 만들어서 그것을 사용하는 방법을 사용할 수 있음.

재귀함수를 사용할 떄는 반드시 종료 조건을 넣어줘야함.

모든 재귀함수는 반복문을 이용하여 동일한 기능을 구현할 수 있음.
재귀함수가 반복문보다 유리한 경우도 있고, 불리한 경우도 있기 때문에 적절하게 사용해야함
(재귀함수를 사용시 훨씬 간결한 코드를 만들경우)

"""

# 예제 1 - 팩토리얼 구현 예제
def fact(n) :
    if n <=1 :
        return 1
    return n * factorial(n-1)

# 예제2 - 유클리드 호제법 : 두개의 자연수에 대한 최대공약수를 구하는 대표적인 알고리즘
"""
유클리드 호제법
1. 두 자연수 A,B에 대하여 (A>B) A를 B로 나눈 나머지를 R이라고 합시다.
2. 이 떄 A와 B의 최대 공약수는 B와 R의 최대공약수와 같다.
"""
def Euclid (x, y) :
    A = max(x,y)
    B = min(x,y)
    
    R = A%B
    
    if R==0 : return B
        
    return Euclid(B,R)

print(Euclid(192,162))
# Out:
# 6

# %%
"""DFS(Depth-First Search)
* DFS 는 깊이 우선 탐색이라고 부르며, 그래프에서 깊은 부분을 우선적으로 탐색하는 알고리즘
* DFS는 스택 자료 구조(혹은 재귀함수)를 사용하며, 구체적인 동작과정은 다음과 같다.
1. 탐색 시작 노드를 스택에 삽입하고 방문처리를 합니다
2. 스택의 최상단 노드에 방문하지 않은 인접한 노드가 하나라도 있으면 그 노드를 스택에 넣고 방문처리 합니다. 방문하지 않은 인접 노드가 없으면 스택에서 최상단 노드를 꺼냅니다.
3. 더이상 2번의 과정을 수행할 수 없을 때까지 반복합니다.
"""
from PIL import Image
# 이미지 열기
im = Image.open('./img/DFS.png')
im

#DFS 메서드 정의
def dfs(graph, v ,visited) :
  visited[v] = True
  print(v, end=' ')
  #현재 노드와 연결된 다른 노드를 재귀적으로 방문
  for i in graph[v] :
    if not visited[i] :
      dfs(graph, i ,visited)

#각 노드가 연결된 정보를 표현
graph = [
  [],
  [2,3,8], #1번이 연결된 노드들의 집합
  [1,7], #2번이 연결된 노드들의 집합
  [1,4,5],
  [3,5],
  [3,4],
  [7],
  [2,6,8],
  [1,7]
] 
# 각 노드가 방문된 정보를 표현(1차원 리스트)
visited = [False]*9

#정의된 DFS 함수를 호출
dfs(graph, 1, visited)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=548x420 at 0x1DE1C5B64A8>

# %%
"""BFS(Breadth-First Search) 너비 우선 탐색
* 그래프에서 가까운 노드부터 우선적으로 탐색하는 알고리즘
* BFS는 큐 자료구조를 이용하며, 구체적인 동작과정은 다음과 같습니다
1. 탐색 시작 노드를 큐에 삽입하고 방문처리를 합니다
2. 큐에서 노드를 꺼낸 뒤에 해당 노드의 인접 노드 중에서 방문하지 않은 노드를 모두 큐에 삽입하고 방문처리합니다
3. 더 이상 2번의 과정을 수행할 수 없을 떄까지 반복합니다. 

* 특정조건에서의 최단경로 문제를 해결하기 위한 목적으로도 효과적으로 사용될 수 있습니다.

[step1] 시작 노드인 '1'을 큐에 삽입하고 방문처리 >>1
[step2] 큐에서 '1을 꺼내 방문하지 않은 인접노드 '2','3',8'을 큐에 넣고 방문처리 합니다 >>2 3 8
[step3] 큐에서 '2'를 꺼내 방문하지 않은 인접노드 '7'을 큐에 삽입하고 방문처리 >> 3 8 7
[step4] 큐에서 '3'을 꺼내 방문하지 않은 인접노드 '4','5'를 큐에 삽입하고 방문처리 >> 8 7 4 5
[step5] 큐에서 '8'을 꺼내고 방문하지 않은 인접노드가 없으므로 무시 >> 7 4 5
[step6] ...

탐색순서 : 1 2 3 8 7 4 5 6

"""

from collections import deque

# BFS 메서드 정의
def bfs(graph, start, visited) :
  #큐(Queue) 구현을 위해 deque 라이브러리를 사용
  queue = deque([start])
  # 현재 노드를 방문처리
  visited[start] = True
  #큐가 빌때까지 계속 반복
  while queue :
    # 큐에서 빌때까지 반복
    v = queue.popleft()
    print(v, end=' ')
    # 아직 방문하지 않은 인접한 원소들을 큐에 삽입
    for i in graph[v] :
      if not visited[i] :
        queue.append(i)
        visited[i] = True

graph = [
  [],
  [2,3,8], #1번이 연결된 노드들의 집합
  [1,7], #2번이 연결된 노드들의 집합
  [1,4,5],
  [3,5],
  [3,4],
  [7],
  [2,6,8],
  [1,7]
] 

#각 노드가 원소에 방문된 정보를 표현(1차원 리스트)
visited = [False] *9

#정의된 BFS 함수를 호출
bfs(graph, 1, visited)

# %%
""" 음료수 얼려 먹기
NxM 크기의 얼음틀이 있습니다. 구멍이 뚫려 있는 부분은 0, 칸막이가 존재하는 부분은 1로 표시됩니다. 구멍이 뚫려 있는 부분끼리 상하좌우로 붙어있는 경우 서로 연결되어 있는 것으로 간주합니다. 이때 얼음틀의 모양이 주어졌을 때 생성되는 총 아이스크림의 개수를 구하는 프로그램을 작성하세요.
다음의 4x5 얼음틀 예시에서는 아이스크림이 총 3개 생성됩니다
4 5
00110
00011
11111
00000
>>3
"""
import sys

input = sys.stdin.readline
size = input().rstrip().split(" ")
data =[list(input().rstrip()) for i in range(int(size[0]))]

move_x=[1,-1,0,0]
move_y=[0,0,1,-1]

visited = [[False] * int(size[1]) for i in range(int(size[0]))]
result = 0

def block(data, point, visited) :
  x= point[0]
  y= point[1]

  visited[y][x] = True

  for i in range(len(move_x)) :
    dx = point[0] + move_x[i]
    dy = point[1] + move_y[i]
    if dx<0 or dx >=int(size[1]) or dy<0 or dy>=int(size[0]) :
      continue
    elif data[y][x] == '0':
      block(data, [dx,dy], visited)
  return visited

for y in range(int(size[0])) :
  for x in range(int(size[1])) :
    if visited[y][x] == False and data[y][x] == '0': 
      visited = block(data, (x, y), visited)
      result+=1
      
print(result)


############################################# 정답
# N,M 을 공백을 기준으로 구분하여 입력받기
n, m = map(int, input().split())

# 2차원 리스트에 맵 정보 입력받기
graph = []
for i in range(n) :
  graph.append(list(map(int,input())))

# DFS로 특정 노드를 방문하고 연결된 노드도 방문
def dfs(x,y) :
  #주어진 범위를 벗어나는 경우에는 즉시 종료
  if x<= -1 or x>=n or y<= -1 or y>=m :
    return False
  #현재 노드를 아직 방문하지 않았다면 
  if graph[x][y] ==0 :
    #해당노드를 방문처리
    graph[x][y] =1
    # 상하좌우 위치들도 모두 재귀적으로 호출
    dfs(x-1, y)
    dfs(x+1, y)
    dfs(x,y-1)
    dfs(x, y+1)
    return True
  return False

# 모든 위치에 대하여 음료수 채우기
result =0
for i in range(n) :
  for j in range(m) :
    #현재 위치에서 DFS 수행
    if dfs(i,j) == True :
      result +=1
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-fb6649a7190f> in <module>()
#      13 input = sys.stdin.readline
#      14 size = input().rstrip().split(" ")
# ---> 15 data = [input().rstrip().split(" ") for i in range(int(size[0]))]
#      16
#      17 move_x=[1,-1,0,0]
#
# ValueError: invalid literal for int() with base 10: ''

# %%
""" 미로탈출
동빈이는 NxM 크기의 직사각형 형태의 미로에 갇혔습니다. 미로에는 여러 마리의 괴물이 있어 이를 피해 탈출해야 합니다
동빈이의 위치는 (1,1)이며 미로의 출구는 (N,M)의 위치에 존재하며 한 번에 한 칸씩 이동할 수 있습니다. 이때 괴물이 있는 부분은 0으로, 괴물이 없는 부분은 1로 표시되어 있습니다. 미로는 반드시 탈출할 수 있는 형태로 제시됩니다
이때 동빈이가 탈출하기 위해 움직여야할 취소 칸의 개수를 구하세요. 칸을 셀때는 시작칸과 마지막 칸을 모두 포함해서 계산합니다.


5 6
101010
111111
000001
111111
111111
"""
import sys
from collections import deque 
input = sys.stdin.readline

size_y, size_x = map(int, input().rstrip().split(" "))

print("y :",size_y, "x :", size_x  )

MAP = []
visited = [ [False]*size_x for i in range(size_y) ] 

for i in range(size_y) :
  MAP.append(list(map(int, input().rstrip())))

print(MAP)

move = [(1,0), (-1,0), (0,1), (0,-1)]

def dfs(x,y) :
  queue = deque()
  queue.append((x,y))

  while queue :
    x,y = queue.popleft()

    for i in range(len(move)) :
      nx = x+move[i][1]
      ny = y+move[i][0]
    
      if nx <0 or ny <0 or nx>=size_x or ny>=size_y :
        continue
      elif MAP[ny][nx] == 0 :
        continue
      elif MAP[ny][nx] == 1 :
        MAP[ny][nx] = MAP[y][x] + 1
        queue.append((nx,ny))

  print("진행중")
  return MAP[size_y-1][size_x -1]

print(dfs(0,0))
